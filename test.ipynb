# %%
from moviepy import VideoFileClip, TextClip, CompositeVideoClip

# %%
video_file = '/Users/michaelmakoto/Documents/backup michael_coffer/michael_coffer3_lowres/LOW08_25122_117/LOW08_mm_25122_mykN_117_20260204_103310_3_post_block_1.mp4'
clip = VideoFileClip(video_file)

# %%
frames = int(clip.fps * clip.duration)

frames
# Out:
# 329
